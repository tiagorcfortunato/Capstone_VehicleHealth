# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configurar estilo dos gráficos
sns.set(style="whitegrid")

# Ler o dataset
df = pd.read_csv("vehicle_sensor_data.csv")

# Visualizar primeiras linhas
df.head()
# Out:
#    engine_temp  vibration  oil_pressure          rpm      speed  failure
# 0    94.967142   1.788120      2.957204  2928.288392  86.965725        0
# 1    88.617357   1.773293      3.255600  2983.672048  85.666472        0
# 2    96.476885   1.102178      3.022095  3032.147439  61.269603        0
# 3   105.230299   1.834955      3.588334  3473.430731  91.591684        0
# 4    87.658466   2.366415      4.457743  2626.391346  50.198346        0

# %%
# Histograma geral
df.hist(figsize=(12,8), bins=30)
plt.suptitle("Distribuições das Variáveis", fontsize=16)
plt.show()

# Matriz de correlação
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Matriz de Correlação")
plt.show()

# %%
# Comparar média das variáveis entre falhas e não falhas
df.groupby('failure').mean()
# Out:
#          engine_temp  vibration  oil_pressure          rpm      speed
# failure
# 0          89.951779   1.989308      3.514875  3008.457895  79.614302
# 1         104.429578   2.788651      2.621482  2980.632552  82.204883
